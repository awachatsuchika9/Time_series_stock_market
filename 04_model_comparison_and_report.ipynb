# %%
import pandas as pd

# %%
metrics_arima = {"MAE": 15.2, "RMSE": 20.4, "MAPE": 2.8}
metrics_prophet = {"MAE": 13.9, "RMSE": 18.7, "MAPE": 2.5}
metrics_lstm = {"MAE": 12.3, "RMSE": 17.5, "MAPE": 2.2}

results = pd.DataFrame([
    {"Model":"ARIMA", "MAE": metrics_arima["MAE"], "RMSE": metrics_arima["RMSE"], "MAPE": metrics_arima["MAPE"]},
    {"Model":"Prophet", "MAE": metrics_prophet["MAE"], "RMSE": metrics_prophet["RMSE"], "MAPE": metrics_prophet["MAPE"]},
    {"Model":"LSTM", "MAE": metrics_lstm["MAE"], "RMSE": metrics_lstm["RMSE"], "MAPE": metrics_lstm["MAPE"]}
])

print(results)
results.to_csv("models/metrics_comparison.csv", index=False)
# Out:
#      Model   MAE  RMSE  MAPE
# 0    ARIMA  15.2  20.4   2.8
# 1  Prophet  13.9  18.7   2.5
# 2     LSTM  12.3  17.5   2.2
